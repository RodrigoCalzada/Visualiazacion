# %% [markdown]
# # Situación Medio Término Rodrigo Calzada Martínez A00828516

# %% [raw]
# En esta presentación de medio término trabajaré con una base de datos que muestra las calificaciones de examenes de writing, listening y math de estudiantes de secundaria en Estados Unidos, lo que llamó mi atención sobre la base de datos es que toman en cuenta la variable de raza y de lunch que come cada alumno ya que desde un primer punto de vista podría parecer que estas variables no afectan al resultado final pero puede suceder que sí afecte, la base de datos muestra las calificaciones de 1000 alumnos (filas) y cuenta con 8 columnas de variables, Las variables de interés son: "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"

# %%
#%pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %ls
# Out:
#  00_00_binder.ipynb
#  00_00_primer_pasos.ipynb
#  01_01_data_types.ipynb
#  01_02_read_iloc_unique_groupby.ipynb
#  02_00_data_wrangling.ipynb
#  02_01_matplotlib_lineplots.ipynb
#  02_01_null_display.ipynb
#  02_02_basic_math.ipynb
#  02_02_null_display.ipynb
#  02_03_basic_math.ipynb
#  03_00_pivot_table.ipynb
#  03_01_lambda_pivot_table.ipynb
#  04_00_matplotlib_scipy.ipynb
#  04_01_histo_Boxplots_FacetGrid.ipynb
#  04_03_hist_axis_gridspec.ipynb
#  04_04_df_filtering.ipynb
# '05_00_boxplots (box-and-whisker plot )_heat_map.ipynb'
#  05_01_area_hist_bar.ipynb
#  07_00_Multivariate_Distributions_hist_scatter.ipynb
#  07_01_Multivariate_Data.ipynb
#  07_02_pie_box_scatter_bubble.ipynb
#  07_03_unit_testing_data_wrangling.ipynb
#  08_00_Regression_Plots.ipynb
# '08_01_Linear Regression with OLS.ipynb'
#  08_02_Linear_and_logistic_regression_modeling.ipynb
# '08_03_Linear Regression using Least Squares.ipynb'
#  09_00_Plotly_Basics.ipynb
#  09_01_Dash_Board.ipynb
# ...

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  StudentsPerformance.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
path = 'datasets/StudentsPerformance.csv'
df = pd.read_csv(path)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
tabla = pd.pivot_table(df,
 columns = ['gender'],
 values = ['math score', 'reading score', 'writing score'],

)
tabla
# Out:
# gender            female       male
# math score     63.633205  68.728216
# reading score  72.608108  65.473029
# writing score  72.467181  63.311203

# %%
tabla.plot(kind = 'barh',
           figsize = (15,8),
alpha = 0.7)
#podemos observar que los hombres obtienen mejores notas en matemáticas que las mujeres mientras que 
#las mujeres obtienen mejores notas que los hombres en exámenes sobre comprensión lectora y escritura

# %% [markdown]
# # ¿El tipo de almuerzo que los alumnos consuman afecta en las calificaciones obtenidas?

# %%
tabla3 = pd.pivot_table(df,
index = ['gender'],
 columns = ['lunch'],
 values = ['math score'],

 )
tabla3
# Out:
#          math score
# lunch  free/reduced   standard
# gender
# female    55.814815  68.124620
# male      62.457831  72.022152

# %%
tabla3.plot(kind='line')
figsize = (15,8)

# %% [raw]
# Podemos concluir que en ambos géneros (hombre y mujer) las calificaciones son bajas cuando consumen alimentos libres o reducidos mientras que las calificaciones son altas si consumen almuerzos estándares.

# %%
tabla4 = pd.pivot_table(df,
index = ['gender'],
 columns = ['lunch'],
 values = ['writing score'],

 )
tabla4
# Out:
#        writing score
# lunch   free/reduced   standard
# gender
# female     66.444444  75.927052
# male       59.126506  65.509494

# %%
tabla4.plot(kind='line')
figsize = (15,8)

# %% [raw]
# Podemos observar que en el mismo caso que en el exámen de matemáticas, en el examen de escritura se obtienen calificaciones más bajas si se consumen alimentos libres o reducidos mientras que las calificaciones on más altas si se consumen alimentos estándar.

# %%
tabla5 = pd.pivot_table(df,
index = ['gender'],
 columns = ['lunch'],
 values = ['reading score'],

 )
tabla5
# Out:
#        reading score
# lunch   free/reduced   standard
# gender
# female     67.386243  75.607903
# male       61.542169  67.537975

# %%
tabla5.plot(kind='line')
figsize = (15,8)

# %% [raw]
# Podemos observar que en el mismo caso que en el exámen de matemáticas y escritura, en el examen de comprensión lectora se obtienen calificaciones más bajas si se consumen alimentos libres o reducidos mientras que las calificaciones on más altas si se consumen alimentos estándar.

# %% [markdown]
# # ¿El prepararse mediante un curso afecta las calificaciones de los estudiantes?

# %%
tabla6 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['test preparation course'],
 values = ['math score']

 )
tabla6
# Out:
#                         math score
# test preparation course  completed       none
# gender
# female                   67.195652  61.670659
# male                     72.339080  66.688312

# %%
tabla6.plot(kind='line')
figsize = (15,8)

# %%
tabla7 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['test preparation course'],
 values = ['writing score']

 )
tabla7
# Out:
#                         writing score
# test preparation course     completed       none
# gender
# female                      78.793478  68.982036
# male                        69.793103  59.649351

# %%
tabla7.plot(kind='line')
figsize = (15,8)

# %%
tabla8 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['test preparation course'],
 values = ['reading score']

 )
tabla8
# Out:
#                         reading score
# test preparation course     completed       none
# gender
# female                      77.375000  69.982036
# male                        70.212644  62.795455

# %%
tabla8.plot(kind='line')
figsize = (15,8)

# %% [raw]
# Podemos concluir que en los 3 examenes (matemáticas, escritura y comprensión lectora) afecta el hecho de que los alumnos se hayan preparado o no para el examen mediante el curso previamente asignado

# %% [markdown]
# # ¿El grado de escolaridad de los padres influye en los resultados de los alumnos?

# %%
tabla9 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['parental level of education'],
 values = ['math score']

 )
tabla9
# Out:
#                                     math score                                \
# parental level of education associate's degree bachelor's degree high school
# gender
# female                               65.250000         68.349206   59.351064
# male                                 70.764151         70.581818   64.705882
#
#
# parental level of education master's degree some college some high school
# gender
# female                            66.500000    65.406780        59.296703
# male                              74.826087    69.009259        67.840909

# %%
tabla9.plot(kind='line')
figsize = (15,8)

# %%
tabla10 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['parental level of education'],
 values = ['writing score']

 )
tabla10
# Out:
#                                  writing score                                \
# parental level of education associate's degree bachelor's degree high school
# gender
# female                                74.00000         78.380952   66.691489
# male                                  65.40566         67.654545   58.539216
#
#
# parental level of education master's degree some college some high school
# gender
# female                            77.638889    74.050847        68.285714
# male                              72.608696    63.148148        61.375000

# %%
tabla10.plot(kind='line')
figsize = (15,8)

# %%
tabla11 = pd.pivot_table(df,
 index = ['gender'],
 columns = ['parental level of education'],
 values = ['reading score']

 )
tabla11
# Out:
#                                  reading score                                \
# parental level of education associate's degree bachelor's degree high school
# gender
# female                               74.120690         77.285714   68.202128
# male                                 67.433962         68.090909   61.480392
#
#
# parental level of education master's degree some college some high school
# gender
# female                            76.805556    73.550847        69.109890
# male                              73.130435    64.990741        64.693182

# %%
tabla11.plot(kind='line')
figsize = (15,8)

# %% [raw]
# Podemos concluir con que el grado de escolaridad de los padres influye de cierta forma en el desempeño de los alumnos, entre mejor sea el grado de escolaridad de los padres, los alumnos obtienen mejores notas aunque no aplica en todos los casos
