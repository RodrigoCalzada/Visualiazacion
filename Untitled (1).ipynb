# %% [markdown]
# Situación Medio Término Rodrigo Calzada Martínez A00828516

# %% [raw]
# En esta presentación de medio término trabajaré con una base de datos que muestra las calificaciones de examenes de writing, listening y math de estudiantes de secundaria en Estados Unidos, lo que llamó mi atención sobre la base de datos es que toman en cuenta la variable de raza y de lunch que come cada alumno ya que desde un primer punto de vista podría parecer que estas variables no afectan al resultado final pero puede suceder que sí afecte, la base de datos muestra las calificaciones de 1000 alumnos (filas) y cuenta con 8 columnas de variables, Las variables de interés son: "gender","race/ethnicity","parental level of education","lunch","test preparation","math score","reading score","writing score"

# %%
#%pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_185/3685185147.py in <module>
# ----> 1 df = pd.read_csv('StudentsPerformance.csv')
#       2 df
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...
